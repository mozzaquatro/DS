# %% [markdown]
# <a href="https://colab.research.google.com/github/mozzaquatro/DS/blob/main/Lecture_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pandas introduction

# %% [markdown]
# ##Series

# %% [markdown]
# ##DataFrames

# %% [markdown]
# ###Structure

# %% [markdown]
# ![1_KOBhtOeFntu6CyJUsCdN0g.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #Numpy exercises

# %% [markdown]
# ##1. Generate a vector with all multiples of 3 from 30 to 99

# %% [markdown]
# ##2. Generate a square array of size (12, 12) filled with ones

# %% [markdown]
# ##3. Generate an array of size (6,3) filled with all numbers between 1 and 18, backwards (18, 17, 16 ...)

# %% [markdown]
# ##4. Generate an array with the same shape as the previous exercise, but filled with zeros. BONUS: use only one method call

# %% [markdown]
# ##5. Generate an array of shape (4, 6) filled with random numbers between -4 and 4

# %% [markdown]
# ##6. Calculate the size of the array generated in the previous exercise

# %% [markdown]
# ##7. Generate an array of shape (6, 3) filled with random numbers between 1 and 18, sorted in ascending order

# %% [markdown]
# ##8. Sum the arrays from the 3rd and 7th exercise together

# %% [markdown]
# ##9. Calculate the sum of all the values from each column in the last generated array

# %% [markdown]
# #Pandas exercises

# %% [markdown]
# ##1. Generate a Pandas series (A) with 12 random numbers between 0 and 12

# %% [markdown]
# ##2. Calculate the frequencies for each of the elements in the previous series

# %% [markdown]
# ##3. Display all the people in people_df whose age is more than the median

# %% [markdown]
# ##4. Generate a second Pandas series (B) with the same criteria as exercise 1 and display only the elements that are in the same positions as the previous series (A)
